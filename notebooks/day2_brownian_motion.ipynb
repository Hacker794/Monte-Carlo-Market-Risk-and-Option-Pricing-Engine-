# %%
import numpy as np 

z = np.random.normal(0, 1)

print(z)
# Out:
# -0.0498051781016073

# %%
z = np.random.normal(0, 1, size=10000)

print(z)
print(z.mean())
print(z.std())
# Out:
# [ 1.43758055  0.35784875 -0.32197126 ...  0.06294314  0.06275846
#   0.45661296]
# -0.00924525459981541
# 0.9905965513169457

# %%
import numpy as np

S = 100
mu = 0.08
sigma = 0.20
dt = 1 / 252

z = np.random.normal(0, 1)

next_price = S * np.exp(
    (mu - 0.5 * sigma**2) * dt
    + sigma * np.sqrt(dt) * z
)

print("Random shock:", z)
print("Next price:", next_price)
# Out:
# Random shock: -0.0862377929758149
# Next price: 99.91519609607728

# %%
for i in range(100):
    z = np.random.normal(0, 1)

    next_price = S * np.exp(
        (mu - 0.5 * sigma**2) * dt
        + sigma * np.sqrt(dt) * z
    )

    print(
        "Shock:", round(z, 3),
        "Next price:", round(next_price, 2)
    )
# Out:
# Shock: 0.871 Next price: 101.13
# Shock: -0.415 Next price: 99.5
# Shock: -0.403 Next price: 99.52
# Shock: 0.471 Next price: 100.62
# Shock: 1.089 Next price: 101.41
# Shock: -0.14 Next price: 99.85
# Shock: -1.35 Next price: 98.34
# Shock: -0.681 Next price: 99.17
# Shock: -0.222 Next price: 99.74
# Shock: 0.427 Next price: 100.56
# Shock: 1.397 Next price: 101.8
# Shock: 0.13 Next price: 100.19
# Shock: 3.014 Next price: 103.89
# Shock: 0.033 Next price: 100.07
# Shock: 0.091 Next price: 100.14
# Shock: 0.638 Next price: 100.83
# Shock: 0.123 Next price: 100.18
# Shock: -1.266 Next price: 98.44
# Shock: -1.024 Next price: 98.74
# Shock: 1.08 Next price: 101.39
# Shock: -0.568 Next price: 99.31
# Shock: -0.578 Next price: 99.3
# Shock: -0.049 Next price: 99.96
# Shock: -0.073 Next price: 99.93
# Shock: -0.925 Next price: 98.86
# Shock: -0.946 Next price: 98.84
# Shock: 1.177 Next price: 101.52
# Shock: -0.358 Next price: 99.57
# Shock: -1.075 Next price: 98.68
# Shock: -0.167 Next price: 99.81
# Shock: 0.725 Next price: 100.94
# Shock: -1.788 Next price: 97.8
# Shock: -0.704 Next price: 99.14
# Shock: -0.469 Next price: 99.43
# Shock: 0.816 Next price: 101.06
# Shock: 0.733 Next price: 100.95
# Shock: -0.28 Next price: 99.67
# Shock: 0.076 Next price: 100.12
# Shock: -0.135 Next price: 99.85
# Shock: 0.193 Next price: 100.27
# Shock: 0.729 Next price: 100.95
# Shock: 0.057 Next price: 100.1
# Shock: 0.532 Next price: 100.7
# Shock: 0.792 Next price: 101.03
# Shock: 0.355 Next price: 100.47
# Shock: -1.113 Next price: 98.63
# Shock: -0.812 Next price: 99.01
# Shock: -0.211 Next price: 99.76
# Shock: 0.348 Next price: 100.46
# Shock: 0.465 Next price: 100.61
# Shock: 1.075 Next price: 101.39
# Shock: 0.528 Next price: 100.69
# Shock: 2.943 Next price: 103.8
# Shock: -1.633 Next price: 97.99
# Shock: 0.586 Next price: 100.76
# Shock: 0.304 Next price: 100.41
# Shock: -0.308 Next price: 99.64
# Shock: 1.535 Next price: 101.98
# Shock: -2.356 Next price: 97.1
# Shock: 1.246 Next price: 101.61
# Shock: -0.513 Next price: 99.38
# Shock: -0.664 Next price: 99.19
# Shock: -0.801 Next price: 99.02
# Shock: 0.741 Next price: 100.96
# Shock: 0.904 Next price: 101.17
# Shock: 1.326 Next price: 101.71
# Shock: 0.27 Next price: 100.36
# Shock: 0.771 Next price: 101.0
# Shock: -1.848 Next price: 97.72
# Shock: -0.309 Next price: 99.63
# Shock: -0.857 Next price: 98.95
# Shock: -0.288 Next price: 99.66
# Shock: -0.856 Next price: 98.95
# Shock: 0.796 Next price: 101.03
# Shock: -2.0 Next price: 97.54
# Shock: -0.892 Next price: 98.91
# Shock: 0.029 Next price: 100.06
# Shock: -1.741 Next price: 97.85
# Shock: 0.024 Next price: 100.05
# Shock: -1.514 Next price: 98.13
# Shock: 0.06 Next price: 100.1
# Shock: 0.347 Next price: 100.46
# Shock: 0.43 Next price: 100.57
# Shock: 1.552 Next price: 102.0
# Shock: 0.729 Next price: 100.95
# Shock: -0.081 Next price: 99.92
# Shock: -2.29 Next price: 97.18
# Shock: -0.734 Next price: 99.1
# Shock: 2.874 Next price: 103.71
# Shock: 1.433 Next price: 101.85
# Shock: 0.223 Next price: 100.3
# Shock: -0.404 Next price: 99.52
# Shock: -0.245 Next price: 99.72
# Shock: 0.98 Next price: 101.27
# Shock: 0.369 Next price: 100.49
# Shock: -2.881 Next price: 96.46
# Shock: -2.064 Next price: 97.46
# Shock: -0.33 Next price: 99.61
# Shock: -2.188 Next price: 97.3
# Shock: -2.016 Next price: 97.52

# %%
import numpy as np
import matplotlib.pyplot as plt

n_steps = 252
dt = 1 / 252

z = np.random.normal(0, 1, size=n_steps)

dW = np.sqrt(dt) * z

W = np.cumsum(dW)

plt.plot(W)
plt.xlabel("Trading Day")
plt.ylabel("Brownian Motion")
plt.title("One Brownian Motion Path")
plt.show()
