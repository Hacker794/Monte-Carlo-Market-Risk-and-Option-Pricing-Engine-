# %%
import numpy as np 

z = np.random.normal(0, 1)

print(z)
# Out:
# 0.1466210866507161

# %%
z = np.random.normal(0, 1, size=10000)

print(z)
print(z.mean())
print(z.std())
# Out:
# [-0.22749908 -0.6192421  -0.18646499 ... -1.55028428 -1.17784198
#  -1.49877499]
# 0.009619959047187715
# 1.0074741204293953

# %%
import numpy as np

S = 100
mu = 0.08
sigma = 0.20
dt = 1 / 252

z = np.random.normal(0, 1)

next_price = S * np.exp(
    (mu - 0.5 * sigma**2) * dt
    + sigma * np.sqrt(dt) * z
)

print("Random shock:", z)
print("Next price:", next_price)
# Out:
# Random shock: -0.2927568153481495
# Next price: 99.65556514813582

# %%
for i in range(5):
    z = np.random.normal(0, 1)

    next_price = S * np.exp(
        (mu - 0.5 * sigma**2) * dt
        + sigma * np.sqrt(dt) * z
    )

    print(
        "Shock:", round(z, 3),
        "Next price:", round(next_price, 2)
    )
# Out:
# Shock: -0.179 Next price: 99.8
# Shock: -0.392 Next price: 99.53
# Shock: -1.233 Next price: 98.48
# Shock: -1.385 Next price: 98.29
# Shock: -0.244 Next price: 99.72
