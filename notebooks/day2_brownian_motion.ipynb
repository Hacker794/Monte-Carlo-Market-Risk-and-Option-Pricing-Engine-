# %%
import numpy as np 

z = np.random.normal(0, 1)

print(z)
# Out:
# 1.6558802018457563

# %%
z = np.random.normal(0, 1, size=10000)

print(z)
print(z.mean())
print(z.std())
# Out:
# [-0.93505747  0.63539291  2.819078   ...  0.11747137 -0.15740591
#  -1.84699469]
# 0.010897386812728246
# 1.0113345093598811
