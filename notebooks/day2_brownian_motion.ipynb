# %%
import numpy as np 

z = np.random.normal(0, 1)

print(z)
# Out:
# -1.4216354426240863

# %%
z = np.random.normal(0, 1, size=10000)

print(z)
# Out:
# [-0.26240334 -0.45621113  0.48381099 ... -1.28041111  1.46271435
#  -0.45221597]
