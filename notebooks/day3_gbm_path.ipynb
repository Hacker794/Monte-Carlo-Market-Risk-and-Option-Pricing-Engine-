# %%
import numpy as np 
import matplotlib.pyplot as plt

S0 = 100
mu = 0.08
sigma = 0.20
T = 1
n_steps = 252
dt = T / n_steps

# %%
z = np.random.normal(0, 1, size=n_steps)

print(z.shape)
# Out:
# (252,)
